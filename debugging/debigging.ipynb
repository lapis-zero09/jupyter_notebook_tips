# %%
from IPython import embed

# %%
def foo():
    a = list([i*2**2+1 for i in range(10)])
    b = list([i if i%2==0 else 0 for i in range(2, 53, 5)])
    c = a + b
    for i in range(len(c)-1):
        idx = int(i/2)
        c[i] += i + a[-idx] + b[idx]
        c[-i] += i + a[idx] + b[-idx] 

    d = len([i*2**2+1 for i in range(-80, 130, 10)])
    embed()
    return c * d

foo()
# Out:
# Python 3.6.5 |Anaconda custom (64-bit)| (default, Apr 26 2018, 08:42:37)
# Type 'copyright', 'credits' or 'license' for more information
# IPython 6.4.0 -- An enhanced Interactive Python. Type '?' for help.
#
# In [1]: d
# Out[1]: 21
#
# In [2]: c
# Out[2]:
# [7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56]
#
# In [3]: exit
# [7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56,
#  7,
#  9,
#  116,
#  120,
#  116,
#  120,
#  126,
#  130,
#  126,
#  130,
#  97,
#  95,
#  99,
#  87,
#  111,
#  89,
#  113,
#  81,
#  125,
#  83,
#  56]

# %%
def foo():
    a = list([i*2**2+1 for i in range(10)])
    b = list([i if i%2==0 else 0 for i in range(2, 53, 5)])
    c = a + b
    for i in range(len(c)-1):
        idx = int(i/2)
        c[i] += i + a[-idx] + b[idx]
        c[-i] += i + a[idx] + b[-idx] 
 
    raise Exception
    d = len([i*2**2+1 for i in range(-80, 130, 10)])
    return c * d

# %%
foo()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-c19b6d9633cf> in <module>()
# ----> 1 foo()
#
# <ipython-input-5-f97bbd32b376> in foo()
#       8         c[-i] += i + a[idx] + b[-idx]
#       9
# ---> 10     raise Exception
#      11     d = len([i*2**2+1 for i in range(-80, 130, 10)])
#      12     return c * d
#
# Exception:

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-c19b6d9633cf> in <module>()
# ----> 1 foo()
#
# <ipython-input-5-f97bbd32b376> in foo()
#       8         c[-i] += i + a[idx] + b[-idx]
#       9
# ---> 10     raise Exception
#      11     d = len([i*2**2+1 for i in range(-80, 130, 10)])
#      12     return c * d
#
# Exception:

# %%
# %debug
# Out:
# > <ipython-input-5-f97bbd32b376>(10)foo()
#       8         c[-i] += i + a[idx] + b[-idx]
#       9
# ---> 10     raise Exception
#      11     d = len([i*2**2+1 for i in range(-80, 130, 10)])
#      12     return c * d
#
# ipdb> h
#
# Documented commands (type help <topic>):
# ========================================
# EOF    cl         disable  interact  next    psource  rv         unt
# a      clear      display  j         p       q        s          until
# alias  commands   down     jump      pdef    quit     source     up
# args   condition  enable   l         pdoc    r        step       w
# b      cont       exit     list      pfile   restart  tbreak     whatis
# break  continue   h        ll        pinfo   return   u          where
# bt     d          help     longlist  pinfo2  retval   unalias
# c      debug      ignore   n         pp      run      undisplay
#
# Miscellaneous help topics:
# ==========================
# exec  pdb
#
# ipdb> l
#       5     for i in range(len(c)-1):
#       6         idx = int(i/2)
#       7         c[i] += i + a[-idx] + b[idx]
#       8         c[-i] += i + a[idx] + b[-idx]
#       9
# ---> 10     raise Exception
#      11     d = len([i*2**2+1 for i in range(-80, 130, 10)])
#      12     return c * d
#
# ipdb> p c
# [7, 9, 116, 120, 116, 120, 126, 130, 126, 130, 97, 95, 99, 87, 111, 89, 113, 81, 125, 83, 56]
# ipdb> c

# %%
'a'
'b'
'c'
# Out:
# 'c'

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
'a'
'b'
'c'
# Out:
# 'a'
# 'b'
# 'c'
